# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
df = pd.read_csv("../datasets/BaseDPEvolucaoMensalCisp.csv", sep=";", decimal=",", encoding="latin1")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37588 entries, 0 to 37587
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cisp                        37588 non-null  int64
#  1   mes                         37588 non-null  int64
#  2   ano                         37588 non-null  int64
#  3   mes_ano                     37588 non-null  object
#  4   aisp                        37588 non-null  int64
#  5   risp                        37588 non-null  int64
#  6   munic                       37588 non-null  object
#  7   mcirc                       37588 non-null  int64
#  8   regiao                      37588 non-null  object
#  9   hom_doloso                  37588 non-null  int64
#  10  lesao_corp_morte            37588 non-null  int64
#  11  latrocinio                  37588 non-null  int64
#  12  cvli                        37588 non-null  int64
# ...

# %%
print(df["regiao"].unique())
# Out:
# ['Capital' 'Baixada Fluminense' 'Interior'
#  'Grande NiterÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â³i' 'Grande Niterói']

# %%
df = df[ df["regiao"].isin(["Capital", "Baixada Fluminense"])]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16472 entries, 0 to 37510
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cisp                        16472 non-null  int64
#  1   mes                         16472 non-null  int64
#  2   ano                         16472 non-null  int64
#  3   mes_ano                     16472 non-null  object
#  4   aisp                        16472 non-null  int64
#  5   risp                        16472 non-null  int64
#  6   munic                       16472 non-null  object
#  7   mcirc                       16472 non-null  int64
#  8   regiao                      16472 non-null  object
#  9   hom_doloso                  16472 non-null  int64
#  10  lesao_corp_morte            16472 non-null  int64
#  11  latrocinio                  16472 non-null  int64
#  12  cvli                        16472 non-null  int64
# ...

# %%
df["risp"].value_counts()
# Out:
# risp
# 1    6905
# 3    5187
# 2    4371
# 5       6
# 6       3
# Name: count, dtype: int64

# %%
df[ df["risp"]==6]
# Out:
#      cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 11     16    1  2003  2003m01    36     6  Rio de Janeiro  3304557  Capital
# 137    16    2  2003  2003m02    36     6  Rio de Janeiro  3304557  Capital
# 263    16    3  2003  2003m03    36     6  Rio de Janeiro  3304557  Capital
#
#      hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 11            3  ...  NaN   NaN     141                      3
# 137           5  ...  NaN   NaN     122                      8
# 263           6  ...  NaN   NaN     132                      5
#
#      encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 11                  1                0                          0
# 137                 2                0                          0
# 263                 4                0                          0
#
#      pol_civis_mortos_serv  registro_ocorrencias  fase
# 11                       0                   973     3
# ...

# %%
## esses dados estão com a risp sendo 6, porem a regiao capital e cisp 16 se referem a barra da tijuca, pertencente a risp 2. 
## como sao poucos dados, assumimos que se trata de um erro de preenchimento, e trocaamos para o valor correto

df.loc[:,"risp"] = df.loc[:,"risp"].replace(6,2)
df["risp"].value_counts()
# Out:
# risp
# 1    6905
# 3    5187
# 2    4374
# 5       6
# Name: count, dtype: int64

# %%
df[ df["risp"]==5]
# Out:
#      cisp  mes   ano  mes_ano  aisp  risp            munic    mcirc  \
# 53     65    1  2003  2003m01    34     5  Magé;Guapimirim  9999982
# 54     66    1  2003  2003m01    34     5             Magé  3302502
# 179    65    2  2003  2003m02    34     5  Magé;Guapimirim  9999982
# 180    66    2  2003  2003m02    34     5             Magé  3302502
# 305    65    3  2003  2003m03    34     5  Magé;Guapimirim  9999982
# 306    66    3  2003  2003m03    34     5             Magé  3302502
#
#                  regiao  hom_doloso  ...  cmp  cmba  ameaca  \
# 53   Baixada Fluminense           4  ...  NaN   NaN      70
# 54   Baixada Fluminense           8  ...  NaN   NaN      53
# 179  Baixada Fluminense           5  ...  NaN   NaN      85
# 180  Baixada Fluminense          11  ...  NaN   NaN      61
# 305  Baixada Fluminense           4  ...  NaN   NaN      98
# 306  Baixada Fluminense           8  ...  NaN   NaN      63
#
# ...

# %%
# mesma logica da anterior, porém aqui a risp correta é 3
df.loc[:,"risp"] = df.loc[:,"risp"].replace(5,3)
df["risp"].value_counts()
# Out:
# risp
# 1    6905
# 3    5193
# 2    4374
# Name: count, dtype: int64

# %%
df["mes_ano"] = pd.to_datetime(
    df.loc[:,'mes_ano'].str.replace('m', '-', regex=False),
    format='%Y-%m'
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16472 entries, 0 to 37510
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cisp                        16472 non-null  int64
#  1   mes                         16472 non-null  int64
#  2   ano                         16472 non-null  int64
#  3   mes_ano                     16472 non-null  datetime64[ns]
#  4   aisp                        16472 non-null  int64
#  5   risp                        16472 non-null  int64
#  6   munic                       16472 non-null  object
#  7   mcirc                       16472 non-null  int64
#  8   regiao                      16472 non-null  object
#  9   hom_doloso                  16472 non-null  int64
#  10  lesao_corp_morte            16472 non-null  int64
#  11  latrocinio                  16472 non-null  int64
#  12  cvli                        16472 non-null  int64
# ...

# %%
df = df[df["ano"] >=2014]

# %%
df.to_pickle('../datasets/dataframe.pkl')
